# %% [markdown]
# ### Week 1: Python Basics - Your First Steps in Programming
# 1. Install Python - follow step-by-step guide for your operating system
# 2. Write your first 'Hello World' program and run it
# 3. Create variables to store your personal information (name, age, city)
# 4. Practice basic math calculations in Python
# 5. Create a list of your favorite foods and learn to access them
#
# ### Project:
# Create a Personal Introduction Program that asks for user's name, age, and hobby, then displays a friendly welcome message with their information
#
# ### Tips & Resources:
#
# Search YouTube: 'Python absolute beginner tutorial no experience'
# Don't worry about mistakes - every error helps you learn
# Practice 30 minutes daily instead of long sessions occasionally
# Use Google Colab if installation is difficult - it runs in browser
# Join free Python communities for beginners on Discord or Reddit

# %% [markdown]
# ### Write your first 'Hello World' program and run it

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### Create variables to store your personal information (name, age, city)

# %%
from IPython.display import Markdown
name = "Sanskruti"
age = 22
city = "Pune"
Markdown(f"My name is **{name}**, **{age}** years old and I live in **{city}**.")
# Out:
# My name is **Sanskruti**, **22** years old and I live in **Pune**.

# %% [markdown]
# ### Practice basic math calculations in Python

# %%
a = int(input("Enter a number:"))
b = int(input("Enter a number:"))

def cal(a,b):
    print("Addition :" , a+b)
    print("Substraction :" , a-b)
    print("Division :" , a/b)
    print("Multiplication :" , a*b)

cal(a,b)
# Out:
# Enter a number: 80
# Enter a number: 40
# Addition : 120
# Substraction : 40
# Division : 2.0
# Multiplication : 3200

# %% [markdown]
# ### Create a list of your favorite foods and learn to access them

# %%
food = ["Pasta", "Paneer", "Pav Bhaji", "Cake", "Rice"]
print(food[0])  #accessing element
print(food[-4])
for i in food:
    print(i, end=" ")
print()
print(food[:5])
print(food[-3:])
# Out:
# Pasta
# Paneer
# Pasta Paneer Pav Bhaji Cake Rice
# ['Pasta', 'Paneer', 'Pav Bhaji', 'Cake', 'Rice']
# ['Pav Bhaji', 'Cake', 'Rice']
